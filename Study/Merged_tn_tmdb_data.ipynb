# %% [markdown]
# I am trying to merge the tn and tmdb databases

# %%
import pandas as pd

# %%
tn_df = pd.read_csv('../zippedData/tn.movie_budgets.csv')
tmdb_df = pd.read_csv('../zippedData/tmdb.movies.csv')

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
orig_tmdb_titles = list(tmdb_df['original_title'])
unique_tmdb_titles = []
single_tmdb_titles =[]
dup_tmdb_titles = []
for title in orig_tmdb_titles:
    if title not in single_tmdb_titles:
        single_tmdb_titles.append(title)
    elif title in dup_tmdb_titles:
        pass
    else:
        dup_tmdb_titles.append(title)
unique_tmdb_titles = single_tmdb_titles + dup_tmdb_titles

# %%
len(unique_tmdb_titles)
# Out:
# 26341

# %%
merged_df = tmdb_df
for tmdb_title in unique_tmdb_titles:
    for tn_title in tn_df['movie']:
        if tmdb_title == tn_title:
            merged_df
# Out:
# How to Train Your Dragon
# Iron Man 2
# Toy Story
# Inception
# Percy Jackson & the Olympians: The Lightning Thief
# Avatar
# Toy Story 3
# Despicable Me
# Megamind
# Toy Story 2
# Alice in Wonderland
# Alice in Wonderland
# The Expendables
# Tangled
# Saw 3D
# The Twilight Saga: Eclipse
# The Book of Eli
# The Bourne Supremacy
# Shutter Island
# The Bourne Identity
# Knight and Day
# The Chronicles of Narnia: The Voyage of the Dawn Treader
# Step Up 3D
# The A-Team
# Bad Boys
# The Last Airbender
# Predators
# The Social Network
# Apollo 13
# Armageddon
# The Bourne Ultimatum
# Clash of the Titans
# Clash of the Titans
# Robin Hood
# Robin Hood
# Nanny McPhee and the Big Bang
# Shrek Forever After
# Easy A
# The Sorcerer's Apprentice
# Grown Ups
# Faster
# The Wolfman
# Unstoppable
# Black Swan
# Centurion
# The Other Guys
# The Town
# Jonah Hex
# The Lovely Bones
# True Grit
# I Spit on Your Grave
# Kick-Ass
# Salt
# Tooth Fairy
# Machete
# El secreto de sus ojos
# Date Night
# ...

# %%
merged_df = tmdb_df
merged_df["test_nz", "test_nz2"] = None
merged_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
merged_df.drop(columns=("test_nz", "test_nz2"), inplace=True)
merged_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb_df.loc[tmdb_df['original_title'] == dup_titles[3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1bd7ec14f4b> in <module>
# ----> 1 tmdb_df.loc[tmdb_df['original_title'] == dup_titles[3]]
#
# NameError: name 'tmdb_df' is not defined
