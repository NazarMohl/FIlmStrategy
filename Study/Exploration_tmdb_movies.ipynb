# %%
import pandas as pd

# %%
tmdb_df = pd.read_csv('../zippedData/tmdb.movies.csv')

# %% [markdown]
# I'm naming the data frame with "tmdb" to represent that this is the "tmdb" data set.

# %%
tmdb_df.keys()
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
tmdb_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# There are 10 columns with no nulls

# %%
len(tmdb_df['id'].unique())
# Out:
# 25497

# %% [markdown]
# id valules are not unique! There may be a column missing that contained some grouping info such as genre and the id was unique within the genre. Will ignore for the time being.

# %%
len(tmdb_df['original_title'].unique()) == len(tmdb_df.index)
# Out:
# False

# %%
len(tmdb_df['original_title'].unique())
# Out:
# 24835

# %% [markdown]
# Movie titles are not unique. There are duplicate names in the rows.

# %%
orig_titles = list(tmdb_df['original_title'])
unique_titles = []
dup_titles = []
for title in orig_titles:
    if title not in unique_titles:
        unique_titles.append(title)
    elif title in dup_titles:
        pass
    else:
        dup_titles.append(title)

# %%
len(unique_titles)
# Out:
# 24835

# %%
len(dup_titles)
# Out:
# 1506

# %%
dup_titles
# Out:
# ['Boy',
#  'Zero',
#  'Alice in Wonderland',
#  'Lies Between Friends',
#  'Toy Story',
#  'Toy Story 2',
#  'TRON: Legacy',
#  'Your Highness',
#  'The Awakening',
#  'Contagion',
#  'Blue Valentine',
#  'Rubber',
#  "Barney's Version",
#  'Zombie Apocalypse',
#  'Detention',
#  'Skateland',
#  'Balada triste de trompeta',
#  'Lucky',
#  'Carancho',
#  'The Myth of the American Sleepover',
#  'West Is West',
#  'Vampires',
#  'American Grindhouse',
#  'Shuffle',
#  'Apart',
#  'Brilliantlove',
#  'The 5th Quarter',
#  'Prinsessa',
#  'Счастье мое',
#  'สวรรค์บ้านนา',
#  'The Confession',
#  'The Elephant in the Living Room',
#  'I Am',
#  'On Strike for Christmas',
#  'Candyman: The David Klein Story',
#  'Exporting Raymond',
#  'Pig',
#  'Some Days Are Better Than Others',
#  'Memory Lane',
#  'Hey, Boo: Harper Lee & To Kill a Mockingbird',
#  'The American Dream',
#  'Lucky',
#  'Lebanon, Pa.',
#  'The Encounter',
#  'BOOM! Das Sexperiment',
#  'The Pact',
#  'The Makeover',
# ...

# %%
tmdb_df.loc[tmdb_df['original_title'] == dup_titles[3]]
# Out:
#       Unnamed: 0      genre_ids      id original_language  \
# 2218        2218  [9648, 10770]  545015                en
# 2290        2290           [18]  101318                en
#
#             original_title  popularity release_date                 title  \
# 2218  Lies Between Friends         0.6   2010-07-31  Lies Between Friends
# 2290  Lies Between Friends         0.6   2010-07-31  Lies Between Friends
#
#       vote_average  vote_count
# 2218           5.0           1
# 2290           4.8           4

# %% [markdown]
# Randomly looking at various sets of records for the same Original title, sometimes the records are exactly the same except for the "unnamed" value. Usually there is some difference in at least one of the other fields such as the range of genre IDs or title.
